# %%
#1009
import sys
data_cnt=int(sys.stdin.readline())
for _ in range(data_cnt):
    a,b=map(int,sys.stdin.readline().split())
    result=[(a**b)%10 for i in range(1,5)][(b%4)-1]
    print(result if result!=0 else 10)
#------------------------- 위아래 풀이 둘다 시간초과 판정을 받는다.ㅠㅠ
n=int(input())
array=[]
for i in range(n):
    a,b=map(int,input().split())
    result=str(a**b)
    answer=int(result[-1])
    array.append(answer)
for i in range(len(array)):
    print(array[i],sep="\n")
#------------------------- 세번째 방법으로 통과할수있다. 반복되는 숫자를 찾는규칙발견하는것이 중요하다
import sys
input = sys.stdin.readline
s = [[], [1], [6, 2, 4, 8], [1, 3, 9, 7], [6, 4], [5], [6], [1, 7, 9, 3], [6, 8, 4, 2], [1, 9]]
t = int(input())
for i in range(t):
    a, b = map(int, input().split())
    a = int(str(a)[-1])
    if a != 0:
        print(s[a][b % len(s[a])])
    else:
        print(10)
#Review) 문제의 규칙을 잘발견하자

# %%
#1085
import sys
x,y,w,h=map(int,sys.stdin.readline().split())
result=min(w-x,x,y,h-y)
print(result)
#Review) 쉽다고 급하게 생각하지말기,문제를 잘 읽고 생각해보기.. 4가지 길중 하나로 가면된다 어떻게든 경계로 가면되는것이다.

# %%
#1247
import sys
for i in range(3):
    result=0
    n=int(sys.stdin.readline())
    for i in range(n):
        a=int(sys.stdin.readline())
        result+=a
    if result==0:
        print("0")
    elif result>0:
        print("+")
    else:
        print("-")
#---------------------아래가 맞은 풀이다.
import sys
tmp=[]
 
for i in range(3):
    for j in range(int(sys.stdin.readline())):
        tmp.append( int(sys.stdin.readline()))
    if sum(tmp)>0: print("+")
    if sum(tmp) == 0: print("0")
    if sum(tmp) < 0: print("-")
    tmp=[]
#Review) import sys를 습관화하도록 하자. 런타임에러에서 걸리면 너무 아까운듯..ㅠ 파이썬 내장함수도 하나씩 뿌셔보기!

# %%
#1267
import sys
n=int(input())
y=0
m=0
for _ in range(n):
    a=int(input())
    if a<30:
        y+=10
    else:
        y+=(a//30)*10+10
    if a<60:
        m+=15
    else:
        m+=(a//60)*15+15
    
if (y>m):
    print("M" ,m)
elif (y<m):
    print("Y ",y)
elif (y==m):
    print("Y M",y)
#----------------------------
n = int(input())
s = list(map(int, input().split()))
y = 0
m = 0
for i in s:
    y += i // 30 * 10 + 10
    m += i // 60 * 15 + 15
if y < m:
    print('Y %d' % y)
elif y > m:
    print('M %d' % m)
else:
    print('Y M %d' % y)
#Review) 두번째 풀이가 맞는데 첫번째 풀이도 Test_Case에 맞게 잘 작동되는데 왜 자꾸 런타임 에러에 뜨는지 모르겟다..하
